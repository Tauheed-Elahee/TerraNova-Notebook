# %% [markdown]
# # Notebook 2 — Concept Extraction
#
# Extracts residual stream hidden states at `L_det` for all 1,879 breast SNOMED concepts using two co-primary methods, and produces the SNOMED→OMOP concept ID mapping required by Block B of notebook 3.
#
# **Inputs**
# - `data/stage1/layer_boundaries.json` → `L_det`, `L_pred`, `L_erased` (written by notebook 1)
# - `data/embeddings-concept-openai/concepts.csv` — 1,879 breast concepts
# - `data/athena/CONCEPT.csv` — Athena OMOP CDM vocabulary table (set `ATHENA_CONCEPT_CSV` below)
#
# **Outputs**
# - `data/stage1/hidden_states_last_token_ldet.npy`    — shape `(n_concepts, d_model)`
# - `data/stage1/hidden_states_mean_pool_ldet.npy`
# - `data/stage1/hidden_states_last_token_lerased.npy`
# - `data/stage1/hidden_states_mean_pool_lerased.npy`
# - `data/stage1/hidden_states_last_token_lmid.npy`    — midpoint of `[L_erased, L_pred]`
# - `data/stage1/hidden_states_mean_pool_lmid.npy`
# - `data/stage1/snomed_omop_map.csv`                   — SNOMED CT ID → OMOP concept_id
#
# **Blocked by:** `1-layer-calibration.ipynb` (must have been run to produce `layer_boundaries.json`)

# %%
# parameters
DATA_DIR           = "../../data/stage1"
CONCEPTS_CSV       = "../../data/embeddings-concept-openai/concepts.csv"
ATHENA_CONCEPT_CSV = "../../data/common/Athena/target/CONCEPT.csv"   # symlink → active Athena vocabulary

# %%
import json
import os
import sys

import numpy as np
import pandas as pd
import torch
from transformer_lens import HookedTransformer

sys.path.insert(0, "../..")
from src.config import MODEL_NAME, TORCH_DTYPE

os.makedirs(DATA_DIR, exist_ok=True)

_boundaries_path = os.path.join(DATA_DIR, "layer_boundaries.json")
if not os.path.exists(_boundaries_path):
    raise FileNotFoundError(
        f"{_boundaries_path} not found. Run 1-layer-calibration.ipynb first."
    )
with open(_boundaries_path) as _f:
    _boundaries = json.load(_f)
L_DET    = _boundaries["L_det"]
L_PRED   = _boundaries["L_pred"]
L_ERASED = _boundaries["L_erased"]

print(f"Model:    {MODEL_NAME}")
print(f"L_DET:    {L_DET}")
print(f"L_PRED:   {L_PRED}")
print(f"L_ERASED: {L_ERASED}")
print(f"dtype:    {TORCH_DTYPE}")
L_MID = (L_ERASED + L_PRED) // 2
if L_ERASED >= L_PRED:
    raise ValueError(
        f"Degenerate calibration: L_ERASED ({L_ERASED}) >= L_PRED ({L_PRED}). "
        "Re-run notebook 1."
    )
print(f"L_MID:    {L_MID}  (midpoint of [L_ERASED={L_ERASED}, L_PRED={L_PRED}])")
import shutil
import time
import psutil as _psutil
from datetime import datetime

def _ts():
    return datetime.now().strftime("%H:%M:%S")

# %%
import subprocess as _sub
_nb_start = time.time()
try:
    _git_hash = _sub.check_output(["git","rev-parse","--short","HEAD"], stderr=_sub.DEVNULL).decode().strip()
except Exception:
    _git_hash = "unknown"
print(f"[{_ts()}] \u2550" * 42 + "\u2550")
print(f"[{_ts()}]  Notebook 2 \u2014 Concept Extraction")
print(f"[{_ts()}]  git: {_git_hash}   DATA_DIR: {DATA_DIR}")
print(f"[{_ts()}]  Python {sys.version.split()[0]}  torch {torch.__version__}  CUDA {torch.version.cuda}")
print(f"[{_ts()}]  RAM: {_psutil.virtual_memory().total/1e9:.1f}GB total  {_psutil.virtual_memory().available/1e9:.1f}GB avail")
print(f"[{_ts()}] \u2550" * 42 + "\u2550")
sys.stdout.flush()

# %%
_cell_start = time.time()
print(f"[{_ts()}] === Load model ==="); sys.stdout.flush()
print(f"[{_ts()}]  Loading {MODEL_NAME} ..."); sys.stdout.flush()
model = HookedTransformer.from_pretrained(MODEL_NAME, dtype=TORCH_DTYPE)
model.eval()
print(f"[{_ts()}]  Model loaded in {time.time()-_cell_start:.0f}s")
print(f"d_model: {model.cfg.d_model}")
_gpu_end = f"  GPU: {torch.cuda.memory_allocated()/1e9:.2f}GB alloc / {torch.cuda.memory_reserved()/1e9:.2f}GB res" if torch.cuda.is_available() else ""
_rss_end = f"  RAM: {_psutil.Process().memory_info().rss/1e9:.2f}GB RSS"
print(f"[{_ts()}]  Cell complete  elapsed {time.time()-_cell_start:.1f}s{_gpu_end}{_rss_end}"); sys.stdout.flush()

# %%
concepts_df = pd.read_csv(CONCEPTS_CSV, dtype=str)
concept_names = concepts_df["preferred_term"].tolist()
n_concepts = len(concept_names)
d_model = model.cfg.d_model

print(f"Concepts: {n_concepts}")
print("Examples:", concept_names[:3])

# %% [markdown]
# ## 2a. Extract hidden states at three calibration landmarks
#
# Three extraction layers span the calibration window established in notebook 1:
#
# | Layer variable | Meaning |
# |---|---|
# | `L_DET` | Beginning of erasure window — subword tokens still strongly present |
# | `L_ERASED` | End of erasure window — subword identity integrated |
# | `L_MID` | Midpoint of `[L_ERASED, L_PRED]` — concept window, pre-commitment |
#
# Both co-primary extraction methods run at each layer:
# - **Method A** — last-token hidden state: `h[:, -1, :]`
# - **Method B** — mean-pool over all token positions: `h.mean(dim=1)`
#
# Yielding six output arrays. Notebook 3 reports correlation with SNOMED ontological distances for all six and identifies empirically which layer best captures concept structure.
#
# Concepts are passed as lowercase, space-prefixed strings (e.g. `" carcinoma of breast"`) to match the form used for `L_det` calibration in notebook 1.
#
# Only the three target layers are cached per forward pass (`names_filter`) to keep memory usage low.

# %%
_cell_start = time.time()
print(f"[{_ts()}] === Extract hidden states ({n_concepts} concepts) ==="); sys.stdout.flush()
EXTRACTION_LAYERS = {
    "ldet":    L_DET,
    "lerased": L_ERASED,
    "lmid":    L_MID,
}

target_hooks = {
    f"blocks.{L}.hook_resid_post"
    for L in EXTRACTION_LAYERS.values()
}

hidden = {
    (tag, method): np.zeros((n_concepts, d_model), dtype=np.float32)
    for tag in EXTRACTION_LAYERS
    for method in ("last", "mean")
}

for i, concept in enumerate(concept_names):
    if i % 200 == 0:
        _el = time.time() - _cell_start
        _rate = f"  ~{_el/i:.3f}s/concept" if i > 0 else ""
        print(f"[{_ts()}]  concept {i}/{n_concepts}  elapsed {_el:.0f}s{_rate}"); sys.stdout.flush()

    tokens = model.to_tokens(" " + concept.lower())

    try:
        with torch.no_grad():
            _, cache = model.run_with_cache(
                tokens,
                names_filter=lambda name: name in target_hooks
            )
    except Exception as _e:
        print(f"[{_ts()}]    SKIP concept {i} {concept!r}: {_e}"); sys.stdout.flush()
        continue

    for tag, L in EXTRACTION_LAYERS.items():
        h = cache[f"blocks.{L}.hook_resid_post"][0]
        hidden[(tag, "last")][i] = h[-1].cpu().float().numpy()
        hidden[(tag, "mean")][i] = h.mean(dim=0).cpu().float().numpy()

print(f"Done. Shape per array: ({n_concepts}, {d_model})")
_gpu_end = f"  GPU: {torch.cuda.memory_allocated()/1e9:.2f}GB alloc / {torch.cuda.memory_reserved()/1e9:.2f}GB res" if torch.cuda.is_available() else ""
_rss_end = f"  RAM: {_psutil.Process().memory_info().rss/1e9:.2f}GB RSS"
print(f"[{_ts()}]  Cell complete  elapsed {time.time()-_cell_start:.1f}s{_gpu_end}{_rss_end}"); sys.stdout.flush()

# %%
_cell_start = time.time()
print(f"[{_ts()}] === Save hidden state arrays ==="); sys.stdout.flush()
_free_gb = shutil.disk_usage(DATA_DIR).free / 1e9
print(f"[{_ts()}]  Disk free: {_free_gb:.1f}GB"); sys.stdout.flush()
for (tag, method), arr in hidden.items():
    method_label = "last_token" if method == "last" else "mean_pool"
    fname = f"hidden_states_{method_label}_{tag}.npy"
    path  = os.path.join(DATA_DIR, fname)
    np.save(path, arr)
    _sz_mb = os.path.getsize(path) / 1e6
    print(f"Saved: {path}  ({_sz_mb:.1f} MB)")
_rss_end = f"  RAM: {_psutil.Process().memory_info().rss/1e9:.2f}GB RSS"
print(f"[{_ts()}]  Cell complete  elapsed {time.time()-_cell_start:.1f}s{_rss_end}"); sys.stdout.flush()

# %% [markdown]
# ## Verification
#
# Checks that all six hidden state files were written with the correct shape and are non-zero. A `FAIL` on any row means the extraction loop did not complete successfully for that array — re-run `d0000007` and `d0000008`.
#
# Expected shape: `(n_concepts, d_model)` = `(1879, 4096)` for Llama-3-8B.

# %%
# Verify all six hidden state files
_expected = (n_concepts, d_model)
_all_ok = True

print(f"Expected shape: {_expected}")
print(f"Extraction layers: { {k: v for k, v in EXTRACTION_LAYERS.items()} }")
print()

for _tag in EXTRACTION_LAYERS:
    for _ml in ("last_token", "mean_pool"):
        _fname = f"hidden_states_{_ml}_{_tag}.npy"
        _path  = os.path.join(DATA_DIR, _fname)
        if not os.path.exists(_path):
            print(f"  MISSING  {_fname}")
            _all_ok = False
            continue
        _arr = np.load(_path)
        _shape_ok   = _arr.shape == _expected
        _nonzero_ok = bool(_arr.any())
        _status = "OK  " if (_shape_ok and _nonzero_ok) else "FAIL"
        print(f"  {_status}  {_fname}  shape={_arr.shape}  non-zero={_nonzero_ok}")
        if not (_shape_ok and _nonzero_ok):
            _all_ok = False

print()
if _all_ok:
    print("All six files verified.")
else:
    raise AssertionError("Verification failed — check output above and re-run extraction cells.")

# %% [markdown]
# ## 2b. SNOMED→OMOP mapping
#
# Block B of `3-geometric-analysis.ipynb` uses KEEP embeddings, which are indexed by OMOP concept IDs. This step produces a mapping from the SNOMED CT IDs in `concepts.csv` to OMOP concept IDs using the Athena vocabulary table.
#
# **Athena download:** https://athena.ohdsi.org — create a free account, search for SNOMED, and download `CONCEPT.csv`. Set `ATHENA_CONCEPT_CSV` in the parameters cell above.
#
# Concepts without an OMOP match are excluded from Block B; the coverage rate is printed below.

# %%
_cell_start = time.time()
print(f"[{_ts()}] === Load Athena SNOMED\u2192OMOP mapping ==="); sys.stdout.flush()
if not os.path.exists(ATHENA_CONCEPT_CSV):
    print(
        f"WARNING: {ATHENA_CONCEPT_CSV} not found.\n"
        "Download CONCEPT.csv from https://athena.ohdsi.org and set ATHENA_CONCEPT_CSV.\n"
        "Skipping SNOMED\u2192OMOP mapping \u2014 Block B of notebook 3 will be unavailable."
    )
else:
    print(f"[{_ts()}]  Reading {ATHENA_CONCEPT_CSV} ..."); sys.stdout.flush()
    athena = pd.read_csv(ATHENA_CONCEPT_CSV, sep="\t", dtype=str, low_memory=False)
    print(f"[{_ts()}]  CSV loaded \u2014 {len(athena):,} rows"); sys.stdout.flush()
    snomed = athena[athena["vocabulary_id"] == "SNOMED"][["concept_code", "concept_id"]]
    print(f"SNOMED concepts in Athena: {len(snomed):,}")

    mapping = concepts_df.merge(
        snomed,
        left_on="concept_id",
        right_on="concept_code",
        how="left",
        suffixes=("_snomed", "_omop")
    )

    mapping = mapping.rename(columns={
        "concept_id_snomed": "snomed_concept_id",
        "concept_id_omop": "omop_concept_id"
    })[["snomed_concept_id", "omop_concept_id"]]

    mapped = mapping["omop_concept_id"].notna().sum()
    print(f"Mapped: {mapped} / {len(mapping)} concepts ({mapped/len(mapping)*100:.1f}%)")
    print(f"Unmapped (excluded from Block B): {len(mapping) - mapped}")

    out_path = os.path.join(DATA_DIR, "snomed_omop_map.csv")
    mapping.to_csv(out_path, index=False)
    print(f"Saved: {out_path}")
_rss_end = f"  RAM: {_psutil.Process().memory_info().rss/1e9:.2f}GB RSS"
print(f"[{_ts()}]  Cell complete  elapsed {time.time()-_cell_start:.1f}s{_rss_end}"); sys.stdout.flush()
print(f"[{_ts()}]  Notebook complete \u2014 total {time.time()-_nb_start:.0f}s elapsed"); sys.stdout.flush()
